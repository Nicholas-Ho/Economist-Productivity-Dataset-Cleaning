# %%
import pandas as pd
import numpy as np
import chardet

# %%
# Don't care! Just making sure the computer can read the file
path = 'appended_data_step1e_fixed_jtosubset_masterfile.csv'

with open(path, 'rb') as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7268578897098108, 'language': ''}

# %%
# Reading the data into a pandas DataFrame, where we can do useful stuff to the data
df = pd.read_csv(path, encoding=result['encoding'])

df.head()
# Out:
#    Unnamed: 0  caper_ID        date paper_code outlet  \
# 0           1       345  28/12/2018     w25414   nber
# 1           2       346   14/5/2021        NaN    vox
# 2           3       663  10/12/2013        NaN    vox
# 3           4       664   28/4/2020        NaN    vox
# 4           5       665    7/1/2021        NaN    vox
#
#                                                title            jel  \
# 0  The Creation And Evolution Of Entrepreneurial ...  G24, G38, L26
# 1  The government as an (effective) venture capit...  G24, G38, L26
# 2                                      Fdi In Africa            NaN
# 3  Covid-19 Could Spur Automation And Reverse Glo...            NaN
# 4  Risk, Resilience, And Recalibration In Global ...            NaN
#
#   prog_areas covid_decision original_name  ... file_name file_num  sample  \
# 0     CF, PR            NaN  Abhishek Dev  ...       RAs      1.0     NaN
# 1        NaN            NaN           NaN  ...       NaN      NaN     NaN
# 2        NaN            NaN  Seric, Adnan  ...       RAs      1.0     NaN
# 3        NaN            NaN  Seric, Adnan  ...       RAs      1.0     NaN
# 4        NaN            NaN  Seric, Adnan  ...   Chryssi      4.0  pooled
#
#   check_not_missing_authors error_seniority    fixed_caper  revision_date  \
# 0                       0.0             0.0            NaN            NaN
# 1                       NaN             NaN  fixed by Khoi            NaN
# 2                       0.0             0.0  fixed by Axel            NaN
# 3                       0.0             0.0  fixed by Axel            NaN
# 4                       0.0             0.0            NaN            NaN
#
#   name_flag Name_corrections Any_notes
# 0         1              NaN       NaN
# 1         1              NaN       NaN
# 2         1              NaN       NaN
# 3         1              NaN       NaN
# 4         1              NaN       NaN
#
# [5 rows x 39 columns]

# %%
# These are only the columns that we want
columns = [
    'name',
    'title',
    'corrected_name',
    'yearPhDgraduation',
    'phd_institution',
    'curr_affiliation',
    'curr_position',
    'pub_affiliation',
    'pub_position'
]

# and we can drop all the other columns
df = df[columns]

df.head()
# Out:
#            name                                              title  \
# 0  Abhishek Dev  The Creation And Evolution Of Entrepreneurial ...
# 1  Abhishek Dev  The government as an (effective) venture capit...
# 2   Adnan Seric                                      Fdi In Africa
# 3   Adnan Seric  Covid-19 Could Spur Automation And Reverse Glo...
# 4   Adnan Seric  Risk, Resilience, And Recalibration In Global ...
#
#   corrected_name  yearPhDgraduation           phd_institution  \
# 0   Abhishek Dev                NaN                       NaN
# 1   Abhishek Dev                NaN           yale university
# 2    Adnan Seric             2010.0  university of st andrews
# 3    Adnan Seric             2010.0  university of st andrews
# 4    Adnan Seric                NaN  university of st andrews
#
#                                     curr_affiliation  \
# 0                            harvard business school
# 1                                    yale university
# 2   united nations industrial development organiz...
# 3   united nations industrial development organiz...
# 4  united nations industrial development organiza...
#
#                             curr_position  \
# 0                      research associate
# 1                             phd student
# 2  Research and Industrial Policy Officer
# 3  Research and Industrial Policy Officer
# 4                        research manager
#
#                                      pub_affiliation  \
# 0                            harvard business school
# 1                                    yale university
# 2                     industrial development officer
# 3             Research and Industrial Policy Officer
# 4  united tions industrial development organizati...
#
#                                         pub_position
# 0                                 research associate
# 1                                        phd student
# 2  united nations industrial development organisa...
# 3  united nations industrial development organisa...
# 4                                   research manager

# %%
# Grouping the data by names!
df_gb = df.groupby(['name'])
names = df_gb.groups.keys()
print(len(names)) # Here we can see that we have 296 unique names in the data
# Out:
# 296

# %%
# For each name (person) we check the few rows for consistency
for name in names:
    group = df_gb.get_group(name)
    
    # these rows
    col_consistency = [
        'yearPhDgraduation',
        'phd_institution',
        'curr_affiliation',
        'curr_position'
    ]
    
    # and replace them with the mode of the column!
    for col in col_consistency:
        try:
            df.loc[df['name']==name, col] = group[col].mode()[0]
        except:
            df.loc[df['name']==name, col] = np.nan # Just a contingency in case there is missing data (spoiler: there was)

df.head(10)
# Out:
#                     name                                              title  \
# 0           Abhishek Dev  The Creation And Evolution Of Entrepreneurial ...
# 1           Abhishek Dev  The government as an (effective) venture capit...
# 2            Adnan Seric                                      Fdi In Africa
# 3            Adnan Seric  Covid-19 Could Spur Automation And Reverse Glo...
# 4            Adnan Seric  Risk, Resilience, And Recalibration In Global ...
# 5  Ahmed Mushfiq Mobarak  Skilled Immigration And Innovation: Evidence F...
# 6  Ahmed Mushfiq Mobarak  Development Effects Of Electrification: Eviden...
# 7  Ahmed Mushfiq Mobarak               Seasonal Migration And Risk Aversion
# 8  Ahmed Mushfiq Mobarak  Gender Differences In Preferences, Intra-House...
# 9  Ahmed Mushfiq Mobarak  International Graduate Students Are Critical T...
#
#           corrected_name  yearPhDgraduation           phd_institution  \
# 0           Abhishek Dev                NaN           yale university
# 1           Abhishek Dev                NaN           yale university
# 2            Adnan Seric             2010.0  university of st andrews
# 3            Adnan Seric             2010.0  university of st andrews
# 4            Adnan Seric             2010.0  university of st andrews
# 5  Ahmed Mushfiq Mobarak             2002.0    university of maryland
# 6  Ahmed Mushfiq Mobarak             2002.0    university of maryland
# 7  Ahmed Mushfiq Mobarak             2002.0    university of maryland
# 8  Ahmed Mushfiq Mobarak             2002.0    university of maryland
# 9  Ahmed Mushfiq Mobarak             2002.0    university of maryland
#
#                                     curr_affiliation  \
# 0                            harvard business school
# 1                            harvard business school
# 2   united nations industrial development organiz...
# 3   united nations industrial development organiz...
# 4   united nations industrial development organiz...
# 5                                    yale university
# 6                                    yale university
# 7                                    yale university
# 8                                    yale university
# 9                                    yale university
#
#                             curr_position  \
# 0                             phd student
# 1                             phd student
# 2  Research and Industrial Policy Officer
# 3  Research and Industrial Policy Officer
# 4  Research and Industrial Policy Officer
# 5                               professor
# 6                               professor
# 7                               professor
# 8                               professor
# 9                               professor
#
#                                      pub_affiliation  \
# 0                            harvard business school
# 1                                    yale university
# 2                     industrial development officer
# 3             Research and Industrial Policy Officer
# 4  united tions industrial development organizati...
# 5                                    yale university
# 6                                    yale university
# 7                                    yale university
# 8                                    yale university
# 9                                    yale university
#
#                                         pub_position
# 0                                 research associate
# 1                                        phd student
# 2  united nations industrial development organisa...
# 3  united nations industrial development organisa...
# 4                                   research manager
# 5                                assistant professor
# 6                                assistant professor
# 7                                assistant professor
# 8                                associate professor
# 9                                associate professor

# %%
# Function to check if the corrected name is longer than the original. If it is, lock it in as 'corrected_name'
def correct_name(row):
    # Less than 31 characters cause the extra python script doesn't like it
    if len(row['corrected_name']) >= len(row['name']) and len(row['corrected_name']) <= 31:
        return row['corrected_name']
    else:
        return row['name']

df['name_corrections'] = df.apply(correct_name, axis=1)

# Drop the old name columns, we don't need them anymore
df = df.drop(['name', 'corrected_name'], axis=1)

df.head()
# Out:
#                                                title  yearPhDgraduation  \
# 0  The Creation And Evolution Of Entrepreneurial ...                NaN
# 1  The government as an (effective) venture capit...                NaN
# 2                                      Fdi In Africa             2010.0
# 3  Covid-19 Could Spur Automation And Reverse Glo...             2010.0
# 4  Risk, Resilience, And Recalibration In Global ...             2010.0
#
#             phd_institution  \
# 0           yale university
# 1           yale university
# 2  university of st andrews
# 3  university of st andrews
# 4  university of st andrews
#
#                                     curr_affiliation  \
# 0                            harvard business school
# 1                            harvard business school
# 2   united nations industrial development organiz...
# 3   united nations industrial development organiz...
# 4   united nations industrial development organiz...
#
#                             curr_position  \
# 0                             phd student
# 1                             phd student
# 2  Research and Industrial Policy Officer
# 3  Research and Industrial Policy Officer
# 4  Research and Industrial Policy Officer
#
#                                      pub_affiliation  \
# 0                            harvard business school
# 1                                    yale university
# 2                     industrial development officer
# 3             Research and Industrial Policy Officer
# 4  united tions industrial development organizati...
#
#                                         pub_position name_corrections
# 0                                 research associate     Abhishek Dev
# 1                                        phd student     Abhishek Dev
# 2  united nations industrial development organisa...      Adnan Seric
# 3  united nations industrial development organisa...      Adnan Seric
# 4                                   research manager      Adnan Seric

# %%
# df.to_csv('processed_productivity_data.csv')

# Grouping the data by names again
df_gb = df.groupby(['name_corrections'])
names = df_gb.groups.keys()

# and writing each to a separate csv!
for name in names:
    group = df_gb.get_group(name)
    group.to_csv(f'data/{name}.csv')
